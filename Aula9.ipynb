# %% [markdown]
# # Aula 9 - Intrudução ao Pandas
# ## Prof. Luis Lamas
#
# Acompanhe os vídeos no canal do SMART Research Group:
# https://www.youtube.com/channel/UCvV5eUanrGET9LWPB8jzWQw

# %% [markdown]
# Nessa aula vamos aprender a manipular dados utilizando a biblioteca Pandas
#
# https://pandas.pydata.org/

# %% [markdown]
# Inicialmente vamos importar as bibliotecas relevantes

# %%
import pandas as pd

# %%
filename = 'owid-covid-data.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1           AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 105005      ZWE    Africa     Zimbabwe  2021-07-21      91120.0     2705.0
# 105006      ZWE    Africa     Zimbabwe  2021-07-22      93421.0     2301.0
# 105007      ZWE    Africa     Zimbabwe  2021-07-23      95686.0     2265.0
# 105008      ZWE    Africa     Zimbabwe  2021-07-24      97277.0     1591.0
# 105009      ZWE    Africa     Zimbabwe  2021-07-25      97894.0      617.0
#
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 105005      ZWE    Africa  Zimbabwe  2021-07-21      91120.0     2705.0
# 105006      ZWE    Africa  Zimbabwe  2021-07-22      93421.0     2301.0
# 105007      ZWE    Africa  Zimbabwe  2021-07-23      95686.0     2265.0
# 105008      ZWE    Africa  Zimbabwe  2021-07-24      97277.0     1591.0
# 105009      ZWE    Africa  Zimbabwe  2021-07-25      97894.0      617.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 105005            2105.571        2809.0        62.0               68.143
# 105006            2078.429        2870.0        61.0               64.571
# 105007            2074.000        2961.0        91.0               63.000
# 105008            2094.857        3050.0        89.0               66.000
# 105009            2039.286        3094.0        44.0               67.429
#
#         ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.008050e+05  100802.00000        99792.000000  9.050500e+04
# mean   1.155242e+06    6104.50001         6116.638123  3.072340e+04
# std    7.856117e+06   37832.07330        37508.284035  1.834065e+05
# min    1.000000e+00  -74347.00000        -6223.000000  1.000000e+00
# 25%    1.435000e+03       2.00000            7.857000  5.800000e+01
# 50%    1.495100e+04      76.00000           94.857000  4.410000e+02
# 75%    1.596790e+05     836.00000          882.857000  4.245000e+03
# max    1.941632e+08  905993.00000       826368.143000  4.159108e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  90660.000000         99792.000000            100270.000000
# mean     145.532484           131.474713             14271.063975
# std      796.025459           740.990236             25723.654267
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105010 entries, 0 to 105009
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               105010 non-null  object
#  1   continent                              100125 non-null  object
#  2   location                               105010 non-null  object
#  3   date                                   105010 non-null  object
#  4   total_cases                            100805 non-null  float64
#  5   new_cases                              100802 non-null  float64
#  6   new_cases_smoothed                     99792 non-null   float64
#  7   total_deaths                           90505 non-null   float64
#  8   new_deaths                             90660 non-null   float64
#  9   new_deaths_smoothed                    99792 non-null   float64
# ...

# %%
df['iso_code']
# Out:
# 0         AFG
# 1         AFG
# 2         AFG
# 3         AFG
# 4         AFG
#          ...
# 105005    ZWE
# 105006    ZWE
# 105007    ZWE
# 105008    ZWE
# 105009    ZWE
# Name: iso_code, Length: 105010, dtype: object

# %%
df['iso_code'].value_counts()
# Out:
# PER    572
# MEX    572
# ARG    572
# THA    569
# TWN    557
#       ...
# TUV     50
# NIU     16
# PCN      7
# TKM      1
# BES      1
# Name: iso_code, Length: 231, dtype: int64

# %%
df.loc[10]
# Out:
# iso_code                                         AFG
# continent                                       Asia
# location                                 Afghanistan
# date                                      2020-03-05
# total_cases                                        4
# new_cases                                          0
# new_cases_smoothed                             0.429
# total_deaths                                     NaN
# new_deaths                                       NaN
# new_deaths_smoothed                                0
# total_cases_per_million                        0.103
# new_cases_per_million                              0
# new_cases_smoothed_per_million                 0.011
# total_deaths_per_million                         NaN
# new_deaths_per_million                           NaN
# new_deaths_smoothed_per_million                    0
# reproduction_rate                                NaN
# icu_patients                                     NaN
# ...

# %%
df.loc[[10,20]]
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 10      AFG      Asia  Afghanistan  2020-03-05          4.0        0.0
# 20      AFG      Asia  Afghanistan  2020-03-15         16.0        1.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 10               0.429           NaN         NaN                  0.0  ...
# 20               1.571           NaN         NaN                  0.0  ...
#
#     extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 10              NaN                597.029                 9.59
# 20              NaN                597.029                 9.59
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 10             NaN           NaN                  37.746
# 20             NaN           NaN                  37.746
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 10                         0.5            64.83                    0.511
# ...

# %%
df.loc[10:20]
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 10      AFG      Asia  Afghanistan  2020-03-05          4.0        0.0
# 11      AFG      Asia  Afghanistan  2020-03-06          4.0        0.0
# 12      AFG      Asia  Afghanistan  2020-03-07          4.0        0.0
# 13      AFG      Asia  Afghanistan  2020-03-08          5.0        1.0
# 14      AFG      Asia  Afghanistan  2020-03-09          7.0        2.0
# 15      AFG      Asia  Afghanistan  2020-03-10          8.0        1.0
# 16      AFG      Asia  Afghanistan  2020-03-11         11.0        3.0
# 17      AFG      Asia  Afghanistan  2020-03-12         12.0        1.0
# 18      AFG      Asia  Afghanistan  2020-03-13         13.0        1.0
# 19      AFG      Asia  Afghanistan  2020-03-14         15.0        2.0
# 20      AFG      Asia  Afghanistan  2020-03-15         16.0        1.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.loc[200:220, ['total_cases', 'total_deaths']]
# Out:
#      total_cases  total_deaths
# 200      38606.0        1421.0
# 201      38641.0        1421.0
# 202      38716.0        1421.0
# 203      38772.0        1427.0
# 204      38815.0        1428.0
# 205      38855.0        1438.0
# 206      38872.0        1438.0
# 207      38897.0        1439.0
# 208      38919.0        1439.0
# 209      39044.0        1443.0
# 210      39074.0        1446.0
# 211      39096.0        1447.0
# 212      39145.0        1448.0
# 213      39170.0        1453.0
# 214      39186.0        1453.0
# 215      39192.0        1455.0
# 216      39227.0        1455.0
# 217      39239.0        1458.0
# 218      39254.0        1460.0
# 219      39268.0        1460.0
# 220      39285.0        1460.0

# %%
df.loc[200:220, 'total_cases':'total_deaths']
# Out:
#      total_cases  new_cases  new_cases_smoothed  total_deaths
# 200      38606.0       34.0              43.143        1421.0
# 201      38641.0       35.0              45.286        1421.0
# 202      38716.0       75.0              45.429        1421.0
# 203      38772.0       56.0              39.714        1427.0
# 204      38815.0       43.0              42.143        1428.0
# 205      38855.0       40.0              44.429        1438.0
# 206      38872.0       17.0              42.857        1438.0
# 207      38897.0       25.0              41.571        1439.0
# 208      38919.0       22.0              39.714        1439.0
# 209      39044.0      125.0              46.857        1443.0
# 210      39074.0       30.0              43.143        1446.0
# 211      39096.0       22.0              40.143        1447.0
# 212      39145.0       49.0              41.429        1448.0
# 213      39170.0       25.0              42.571        1453.0
# ...

# %%
df.iloc[10,3]
# Out:
# '2020-03-05'

# %%
df.iloc[200:220, [4,7]]
# Out:
#      total_cases  total_deaths
# 200      38606.0        1421.0
# 201      38641.0        1421.0
# 202      38716.0        1421.0
# 203      38772.0        1427.0
# 204      38815.0        1428.0
# 205      38855.0        1438.0
# 206      38872.0        1438.0
# 207      38897.0        1439.0
# 208      38919.0        1439.0
# 209      39044.0        1443.0
# 210      39074.0        1446.0
# 211      39096.0        1447.0
# 212      39145.0        1448.0
# 213      39170.0        1453.0
# 214      39186.0        1453.0
# 215      39192.0        1455.0
# 216      39227.0        1455.0
# 217      39239.0        1458.0
# 218      39254.0        1460.0
# 219      39268.0        1460.0

# %%
df.iloc[200:220, 4:7]
# Out:
#      total_cases  new_cases  new_cases_smoothed
# 200      38606.0       34.0              43.143
# 201      38641.0       35.0              45.286
# 202      38716.0       75.0              45.429
# 203      38772.0       56.0              39.714
# 204      38815.0       43.0              42.143
# 205      38855.0       40.0              44.429
# 206      38872.0       17.0              42.857
# 207      38897.0       25.0              41.571
# 208      38919.0       22.0              39.714
# 209      39044.0      125.0              46.857
# 210      39074.0       30.0              43.143
# 211      39096.0       22.0              40.143
# 212      39145.0       49.0              41.429
# 213      39170.0       25.0              42.571
# 214      39186.0       16.0              41.286
# 215      39192.0        6.0              39.000
# 216      39227.0       35.0              26.143
# 217      39239.0       12.0              23.571
# 218      39254.0       15.0              22.571
# ...
